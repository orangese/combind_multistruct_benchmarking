# %% [markdown]
# # Show contributions to ComBind Score in a Heiracrchical Fashion

# %%
from scoring import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prot = 'JAK2'
stats = 'stats19/stats'
scores = 'stats19/pdb/standard/1.0-mcss_contact_hbond_sb'
fname = 'pdb.sc'
struct = '2B7A'

print('results {0}/scores/{1}/{2}, {0}, {3}, confgen_es4'.format(prot, scores, fname, struct))

cluster, glide_cluster, best_cluster, sc = load(prot, stats, scores, fname, struct)
# Out:
# results JAK2/scores/stats7/pdb/standard/1.0-mcss_contact_hbond_sb/pdb.sc, JAK2, 2B7A, confgen_es4

# %% [markdown]
# # Statistics for calculation

# %%
stats_plot(sc)

# %% [markdown]
# # Interactions

# %%
ligands = list(cluster)
for feature in ['sb', 'hbond', 'contact']:
    print('ComBind v. Glide for {}'.format(feature))
    sc.ps.gel_plot(cluster, {k: 0 for k, v in cluster.items()}, feature, ligands)
    print('ComBind v. Best for {}'.format(feature))
    sc.ps.gel_plot(cluster, best_cluster, feature, [ligand for ligand in best_cluster])
# Out:
# ComBind v. Glide for sb
# ComBind - Glide: -0.5718071512507477
# ComBind v. Best for sb
# /Users/jpaggi/miniconda3/lib/python3.7/site-packages/matplotlib/image.py:865: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=-0.5, top=-0.5
#   self.axes.set_ylim((ymin, ymax), auto=None)
# ComBind - Glide: 0.0
# ComBind v. Glide for hbond
# ComBind - Glide: -0.8411578985905621
# ComBind v. Best for hbond
# ComBind - Glide: 1.9855390151464094
# ComBind v. Glide for contact
# ComBind - Glide: 91.93461587353394
# ComBind v. Best for contact
# ComBind - Glide: 24.44988248296884

# %% [markdown]
# # Performance

# %%
performance_plot(cluster, glide_cluster, sc)
# Out:
# 2W1I_lig 8.32327059894 8.32327059894
# 3E64_lig 2.83476782119
# 3FUP_lig 2.03679326459
# 3JY9_lig 4.69144418324
# 3KCK_lig 4.18732319659
# 3TJC_lig 2.02510220042
# 3TJC_lig 8.79318535733 8.90311578216
# 3TJD_lig 3.80072791987
# 3UGC_lig 10.1806456701
# 3UGC_lig 10.3590664102 11.2613329791

# %% [markdown]
# # Energy Differences

# %%
energy_plot(cluster, glide_cluster, sc)
# Out:
# Cluster1 - Cluster2 = -2.5232185576770862 for mcss
# Cluster1 - Cluster2 = 103.39790555401316 for contact
# Cluster1 - Cluster2 = 61.75668690332827 for hbond
# Cluster1 - Cluster2 = 0.0 for sb

# %%
# Likelihood of ComBind - best in context of ComBind

ligand = '3E62_lig'
pose = best_cluster[ligand]
mut = {k:v for k, v in cluster.items()}
mut[ligand] = pose

energy_plot(cluster, mut, sc)
# Out:
# Cluster1 - Cluster2 = 0.0 for mcss
# Cluster1 - Cluster2 = 9.80370647972035 for contact
# Cluster1 - Cluster2 = 0.0 for hbond
# Cluster1 - Cluster2 = 0.0 for sb

# %%
# Likelihood of ComBind - best in context of best

ligand = '2W1I_lig'
mut = {k:v for k, v in best_cluster.items()}
mut[ligand] = cluster[ligand]

energy_plot(mut, best_cluster, sc)
# Out:
# Cluster1 - Cluster2 = 0.0 for mcss
# Cluster1 - Cluster2 = 5.256762785684858 for contact
# Cluster1 - Cluster2 = -4.928260536995797 for hbond
# Cluster1 - Cluster2 = 0.0 for sb

# %%
best_cluster
# Out:
# {'2W1I_lig': 1,
#  '2XA4_lig': 0,
#  '3E62_lig': 0,
#  '3E63_lig': 0,
#  '3IO7_lig': 0,
#  '3IOK_lig': 3,
#  '3KRR_lig': 8,
#  '3LPB_lig': 0,
#  '3Q32_lig': 12,
#  '3RVG_lig': 0,
#  '3ZMM_lig': 0,
#  '4AQC_lig': 0,
#  '4BBE_lig': 0}
