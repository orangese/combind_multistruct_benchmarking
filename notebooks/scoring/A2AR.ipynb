# %% [markdown]
# # Show contributions to ComBind Score in a Heiracrchical Fashion

# %%
from scoring import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prot = 'A2AR'
stats = 'stats7/stats'
scores = 'stats7/pdb/standard/1.0-mcss_contact_hbond_sb'
fname = 'pdb.sc'
struct = '2YDO'

cluster, glide_cluster, best_cluster, sc = load(prot, stats, scores, fname, struct)

# %% [markdown]
# # Statistics for calculation

# %%
stats_plot(sc)

# %% [markdown]
# # Interactions

# %%
ligands = list(cluster)
for feature in ['sb', 'hbond', 'contact']:
    print('ComBind v. Glide for {}'.format(feature))
    sc.ps.gel_plot(cluster, {k: 0 for k, v in cluster.items()}, feature, ligands)
    print('ComBind v. Best for {}'.format(feature))
    sc.ps.gel_plot(cluster, best_cluster, feature, [ligand for ligand in best_cluster])
# Out:
# ComBind v. Glide for sb
# ComBind - Glide: 0.40553676520989246
# ComBind v. Best for sb
# ComBind - Glide: -1.1382541864583713
# ComBind v. Glide for hbond
# ComBind - Glide: 4.438065233158249
# ComBind v. Best for hbond
# ComBind - Glide: 7.854032068004372
# ComBind v. Glide for contact
# ComBind - Glide: 55.45734933945058
# ComBind v. Best for contact
# ComBind - Glide: 126.51539985692126

# %% [markdown]
# # Performance

# %%
performance_plot(cluster, glide_cluster, sc)
# Out:
# 3EML_lig 9.8494194404 9.8494194404
# 3REY_lig 3.52855947327
# 3UZC_lig 2.31282743352
# 5IU7_lig 10.8365316387 12.0823947745
# 5IU8_lig 9.89167653287 10.5895243408
# 5IUA_lig 11.4185718801 11.1483700425
# 5IUB_lig 11.2273668704 11.3849803887
# 5N2R_lig 4.95279193224
# 5OLO_lig 3.40655597855
# 5OLO_lig 8.59389127613 8.34056749576
# 5OLV_lig 1.64338612563 8.6426022916

# %% [markdown]
# # Energy Differences

# %%
energy_plot(cluster, glide_cluster, sc)
# Out:
# Cluster1 - Cluster2 = 10.17395612501169 for mcss
# Cluster1 - Cluster2 = 1.8471387725923223 for contact
# Cluster1 - Cluster2 = 180.46847647813723 for hbond
# Cluster1 - Cluster2 = 0.0 for sb

# %%
ligand = '5OLV_lig'
pose = 0
mut = {k:v for k, v in cluster.items()}
mut[ligand] = pose

energy_plot(cluster, mut, sc)
# Out:
# Cluster1 - Cluster2 = 0.0 for mcss
# Cluster1 - Cluster2 = -2.3812620741218975 for contact
# Cluster1 - Cluster2 = 50.45440435443861 for hbond
# Cluster1 - Cluster2 = 0.0 for sb

# %%
ligand = '5OLV_lig'
pose = 0
mut = {k:v for k, v in best_cluster.items()}
mut[ligand] = pose

energy_plot(cluster, mut, sc)
# Out:
# Cluster1 - Cluster2 = -20.24541985415606 for mcss
# Cluster1 - Cluster2 = 99.92179192466986 for contact
# Cluster1 - Cluster2 = 94.97146098520017 for hbond
# Cluster1 - Cluster2 = -1.3750973450707071 for sb
