# %%
from screening import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

def run(affinity_thresh, xtal_thresh, active_thresh):
    data = plot_num_all(affinity_thresh, xtal_thresh, active_thresh, plot=False)
    aggregrate(data, 'ComBind', 'Glide', r'{} - {} $\tau$')
    aggregrate(data, 'ComBind', 'AUTOQSAR', r'{} - {} $\tau$')

# %%
run(0, 2, 2)

# %%
run(-5, 2, 2)

# %%
run(-6, 2, 2)

# %%
run(-7, 2, 2)

# %% [markdown]
# # Distinct from known

# %%
run(0, .4, .4)

# %%
run(-5, .4, .4)

# %%
run(-6, .4, .4)

# %%
run(-7, .4, .4)

# %%
run(0, .3, .3)

# %%
run(-5, .3, .3)

# %%
run(-6, .3, .3)

# %%
run(-7, .3, .3)

# %% [markdown]
# # Different from XTAL ligand

# %%
run(0, .4, 2)

# %%
run(-5, .4, 2)

# %%
run(-6, .4, 2)

# %%
run(-7, .4, 2)
